# %%
import pandas as pd

df = pd.read_csv("../data/raw/fraud_oracle.csv")

print(df.head)
print(df.shape)
# Out:
# (15420, 33)

# %% [markdown]
# # Insurance Claim Fraud Detection
#
# ## Business Understanding
#
# ### Problem
#
# Insurance companies receive many insurance claims.
# Some claims may be fraudulent.
#
# Fraudulent claims can cause financial losses for insurance companies.
#
# ### Goal
#
# Our goal is to build a Machine Learning model that can predict
# whether an insurance claim is fraudulent or not.
#
# ### Machine Learning Task
#
# This is a Classification problem.
#
# The model will predict:
#
# - Fraudulent claim
# - Legitimate claim
#
# ### Project Objectives
#
# 1. Clean the insurance claim data.
# 2. Understand the data.
# 3. Find patterns related to fraud.
# 4. Build Machine Learning models.
# 5. Evaluate the models.
# 6. Explain model predictions using SHAP.
# 7. Build a Streamlit dashboard.
